# %% [markdown]
# # Phase 1 – Data Acquisition
#
# Download all raw data sources needed for the school noise analysis.

# %%
# %pip install requests tqdm geopandas rasterio rasterstats scipy pandas numpy matplotlib statsmodels mgwr

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..'))
from src.data_acquisition import (
    download_nces_schools, download_nces_ccd,
    download_ejscreen, check_manual_downloads
)

# %% [markdown]
# ## Download Automated Sources

# %%
schools_dir = download_nces_schools()
print('Schools directory:', schools_dir)

# %%
ccd_dir = download_nces_ccd()
print('CCD directory:', ccd_dir)

# %%
ej_path = download_ejscreen()
print('EJScreen CSV:', ej_path)

# %% [markdown]
# ## Check Manual Downloads
#
# The following datasets require manual download (see README for links):

# %%
check_manual_downloads()
